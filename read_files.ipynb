# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df = pd.read_parquet('merchants_reference.parquet')
df
# Out:
#      merchant_id           merchant_name   mcc merchant_country  \
# 0     MER_000000              Google Ads  7311          Ireland
# 1     MER_000001                Meta Ads  7311          Ireland
# 2     MER_000002              TikTok Ads  7311        Singapore
# 3     MER_000003           Yandex Direct  7311           Russia
# 4     MER_000004            LinkedIn Ads  7311          Ireland
# ...          ...                     ...   ...              ...
# 2160  MER_002160  Hotel/Lodging(Cod_9271  3705       Kazakhstan
# 2161  MER_002161  Hotel/Lodging(Cod_1934  3705       Kazakhstan
# 2162  MER_002162   Airline(Code3236_1010  3236       Kazakhstan
# 2163  MER_002163   Airline(Code3236_2766  3236       Kazakhstan
# 2164  MER_002164   Airline(Code3236_6865  3236       Kazakhstan
#
#       recurring_capable
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# ...                 ...
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df_2 = pd.read_parquet('business_cards_MDQ.parquet')
df_2
# Out:
#         transaction_date transaction_timestamp  transaction_amount_kzt   mcc  \
# 0             2025-10-01   2025-10-01 00:00:00                  180976  7372
# 1             2025-10-01   2025-10-01 00:00:00                  153206  7372
# 2             2025-10-01   2025-10-01 00:00:00                  197106  7372
# 3             2025-10-01   2025-10-01 00:01:00                  189598  7372
# 4             2025-10-01   2025-10-01 00:03:00                  700571  7311
# ...                  ...                   ...                     ...   ...
# 2997588       2026-03-31   2026-03-31 23:05:10                   28768  7311
# 2997589       2026-03-31   2026-03-31 23:15:14                   49167  8931
# 2997590       2026-03-31   2026-03-31 23:21:08                   21450  5733
# 2997591       2026-03-31   2026-03-31 23:27:19                   49854  5085
# 2997592       2026-03-31   2026-03-31 23:59:30                  492544  7399
#
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df_3 = pd.read_parquet('consumer_cards_MDQ.parquet')
df_3
# Out:
#         transaction_date transaction_timestamp  transaction_amount_kzt   mcc  \
# 0             2025-10-01   2025-10-01 00:04:00                    4788  4814
# 1             2025-10-01   2025-10-01 00:10:00                    5240  4814
# 2             2025-10-01   2025-10-01 00:12:00                    4576  4814
# 3             2025-10-01   2025-10-01 00:37:00                    6078  4814
# 4             2025-10-01   2025-10-01 00:37:00                    6042  4814
# ...                  ...                   ...                     ...   ...
# 9832482       2026-03-31   2026-03-31 23:34:37                     815  5462
# 9832483       2026-03-31   2026-03-31 23:40:14                   30385  3295
# 9832484       2026-03-31   2026-03-31 23:40:28                   21928  4814
# 9832485       2026-03-31   2026-03-31 23:41:41                  135564  5541
# 9832486       2026-03-31   2026-03-31 23:48:24                    3557  4899
#
# ...
